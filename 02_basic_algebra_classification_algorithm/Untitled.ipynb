# %%
import pandas as pd

import numpy as np

from sklearn.datasets import make_circles

# %%
dataset = make_circles(n_samples = 200,noise = 0.5, factor = 0.5)

# %%
x1 = []
x2 = []
for point in dataset[0]:
    x1.append(point[0])
    x2.append(point[1])

# %%
x1
# Out:
# [-0.07559674131490363,
#  -1.1980543000131243,
#  -0.3600290474708842,
#  -0.8326088472773525,
#  -0.47013511469234404,
#  -0.9555102463574308,
#  0.7560906910953251,
#  -0.7718296018049525,
#  -0.09235977578575197,
#  -0.11047374630134732,
#  1.0916129717158634,
#  -0.18800586406915132,
#  -0.40648112653952617,
#  0.5599461555042398,
#  0.016308169088592506,
#  1.0012462418487686,
#  -0.042547920888483304,
#  -0.19086193199003504,
#  0.7595783302998221,
#  -0.7538930223491529,
#  -1.2570377618761033,
#  0.44189152383394076,
#  0.27005213774721204,
#  -0.2053108394094404,
#  -0.18759915370788494,
#  0.29391927247658245,
#  -0.39438986008548027,
#  0.5319074764912288,
#  -1.305936511916112,
#  -0.46948369778794885,
#  0.6612443634152128,
#  0.4419987529640981,
#  -0.2058930234393026,
#  -0.27640205437709076,
#  0.9345944425214063,
#  0.9911040246025995,
#  -0.7318068105632531,
#  -0.4794111295631801,
#  0.3474478553598251,
#  -0.8932599377975401,
#  0.383620604380799,
# ...

# %%
x2
# Out:
# [-0.323943532337153,
#  0.21221049039476136,
#  -1.3944131958522301,
#  -0.04500131447208944,
#  0.48933433237655877,
#  -0.6828851820852537,
#  -0.42730812809170904,
#  0.022332911041553327,
#  -0.12066690925837276,
#  -0.1312273459079044,
#  1.0753491989346378,
#  0.7120082418115424,
#  0.4402498342296912,
#  -0.6414842072968684,
#  0.6662750419006185,
#  -0.6715807732638925,
#  0.452118611349126,
#  0.11807823876917846,
#  -0.7995365638492957,
#  0.9738580703026349,
#  -0.7347758104299256,
#  -0.583109533346483,
#  0.6940977157666345,
#  0.9478745800032488,
#  0.7468344915833378,
#  -0.2578382590529156,
#  -0.36332278331768564,
#  -0.7931240546884089,
#  -0.3903912383092502,
#  1.4156226411013302,
#  -0.18695097113943232,
#  -1.509829993126598,
#  0.7733419012696026,
#  0.7846911775727119,
#  0.8767780690438065,
#  0.3732837300090745,
#  -0.09170403605831934,
#  0.253112291692177,
#  -0.4843535874485244,
#  -0.8212412367026733,
#  -0.10649606002539103,
#  -0.9376492479798466,
# ...
